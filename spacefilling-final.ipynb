# %%
from pymoo.factory import get_visualization, get_reference_directions
from pymoo.factory import get_performance_indicator
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from pandas.plotting import scatter_matrix
import pandas as pd
import methods as m
# %matplotlib widget

np.random.seed(101)

M = 3
N = 80

# rd = ref_dirs = get_reference_directions("energy", M, N, seed=1)
# print(ref_dirs)
# print("Hypervolume:", round(hv.do(ref_dirs) * 100, 2), "%")
# get_visualization("scatter").add(ref_dirs).show()

rd = m.dich(50)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
img = ax.scatter(rd[:,0], rd[:,1], rd[:,2], marker='o', depthshade=False, edgecolors='black', color='dodgerblue',s=20)
# img = ax.scatter(rd[:,0], rd[:,1], rd[:,2], c=rd[:,3], cmap=plt.hot())
ax.view_init(30,45)
ax.plot([1,0], [0,0], [0,0], color='gray', linewidth=0.7, linestyle='--', dashes=(5, 3))
ax.plot([0,0], [1,0], [0,0], color='gray', linewidth=0.7, linestyle='--', dashes=(3, 3))
ax.plot([0,0], [0,0], [1,0], color='gray', linewidth=0.7, linestyle='--', dashes=(3, 3))

ax.plot([1,0], [0,1], [0,0], color='black',linewidth=0.4)
ax.plot([1,0], [0,0], [0,1], color='black',linewidth=0.4)
ax.plot([0,0], [1,0], [0,1], color='black',linewidth=0.4)

ax.text(0.1,1,-0.1, "(0,1,0)")
ax.text(1,-0.2,-0.3, "(1,0,0)")
ax.text(0.15,-0,1.15, "(0,0,1)")

ax.grid(False)
plt.axis('off')
plt.show()

plt.savefig('images/random_dis.png', bbox_inches='tight')

# df = pd.DataFrame(rd, columns=['X', 'Y', 'Z', 'W'])
# scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# sns.pairplot(df)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
