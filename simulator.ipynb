# %%
import numpy as np
import methods as m
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %%
sd = np.random.randint(low=10, high=10000)
sd = 1924
print("seed", sd)
np.random.seed(sd)

map = m.getmap3D()
map2 = m.getLimitedMap3D()
pts = m.get_random_extSimplex_pt(50, 2)

ptsfinal = m.energy_distrubute(pts)
m.plot_points3D(map2, pts)
m.plot_points3D(map, ptsfinal)
# Out:
# seed 1924
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
