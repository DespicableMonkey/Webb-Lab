# %%
import numpy as np
import methods as m
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
sd = np.random.randint(low=10, high=10000)
sd = 843
print("seed", sd)
np.random.seed(sd)
#8569

# vgm = m.performance_metrics.get_indicator("vgm")
# dmin = m.performance_metrics.get_indicator("dmin")
# rad = m.performance_metrics.get_indicator("rad-simplexprism", radius=0.1)


# ax = m.getLimitedMap3D(name=True,X=0,Y=45,title="Horizontal")
# ax2 = m.getLimite2dMap3D(name=True,X=0,Y=45, title="Vertical")
# ax3 = m.getLimitedMap3D(name=True,X=0, Y=45, title="Duplicated")
# 20 -135

# ax5 = m.getmapaxdef2D()
# ax6 = m.getmapaxdef2D()
# ax7 = m.getmapaxdef2D()


# pts = m.multilayer_projection_DP_Maximin_Energy(15, 3)
# pts2 = m.segmented_simplex_projection_DP_Maximin_Energy(45, 3)
# pts3 = m.duplicated_projected_DP_Energy(15,3)


# ax.plot([0, 1], [1, 0], [0.33, 0.33])
# ax.plot([0, 1], [1, 0], [0.66, 0.66])
# bin_starts_x = np.linspace(0, 1, 4)
# bin_starts_y = np.linspace(1, 0, 4)
# for i in range(4):
#     ax2.plot([bin_starts_x[i], bin_starts_x[i]], [bin_starts_y[i], bin_starts_y[i]], [0, 1])
# m.plot_points3D(ax, pts)
# m.plot_points3D(ax2, pts2)
# m.plot_points3D(ax3, pts3)
# V1 = (((1-pts[:,0])**2 + pts[:,1]**2)**(1/2))
# V2 = (((1-pts2[:,0])**2 + pts2[:,1]**2)**(1/2))
# V3 = (((1-pts3[:,0])**2 + pts3[:,1]**2)**(1/2))
# ax.text(1.3,0,1.1,s=m.getMetricString(pts,vgm=vgm,dmin=dmin,rad=rad))
# ax2.text(1.3,0,1.1,s=m.getMetricString(pts2,vgm=vgm,dmin=dmin,rad=rad))
# ax3.text(1.3,0,1.1,s=m.getMetricString(pts3,vgm=vgm,dmin=dmin,rad=rad))
# ax4.text(1.3,0,1.1,s=m.getMetricString(pts4,vgm=vgm,dmin=dmin,rad=rad))
 
# m.drawheatmap(ax5, V1, pts[:,2], 64)
# m.drawheatmap(ax6, V2, pts2[:,2], 64)
# m.drawheatmap(ax7, V3, pts3[:,2], 64)
pts4, boundpts = m.no_segmentation_projection_DP_Maximin_Energy(45, sq_pts=10)

ax = m.drawSimplexExtend("", pts4, map=m.getmap3D())
m.drawExtra(ax, boundpts)




V4 = (((1-pts4[:,0])**2 + pts4[:,1]**2)**(1/2))


m.heatmap_nice("Distribution Density Heatmap", V4, pts4[:,2], 64)
m.drawKDPlot(V4, 0.2, 1.4, "Density on Simplex", ax=m.getmap2D())    
m.drawKDPlot(pts4[:,2], 0.35, 1, "Density on DP Dimension", height=1.5,  ax=m.getmap2D())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# seed 843
# /Users/despicablemonkey/Desktop/Webb/methods.py:724: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
